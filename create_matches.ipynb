# %% [markdown]
# # Match People

# %%
import pandas as pd
from person_matching_functions import *
from person_matcher import PersonMatcher

# %%
census = pd.read_csv('data/1790 Census Data Complete.csv')
baptisms = pd.read_csv('data/Baptisms.csv')

# %%
census.dropna(how='all', inplace=True)
baptisms.dropna(how='all', inplace=True)

# %%
census['ecpp_id'] = range(1, len(census) + 1)
baptisms['#ID'] = range(1, len(baptisms) + 1)

# %%
# padrones
# census['Ego_Last Name'] = (census['Ego_Paternal Last Name'].fillna('') + ' ' +
#                             census['Ego_ Maternal Last Name'].fillna('')).str.strip()

# %%
census.columns
# Out:
# Index(['Current_Location', 'First', 'First_Normalized', 'Last',
#        'Last_Normalized', 'Race', 'Rank', 'Gender', 'Origin', 'Age',
#        'Spouse_First', 'Spouse_Last', 'Father_First', 'Father_Last',
#        'Mother_First', 'Mother_Last', 'Child1', 'Child2', 'Child3', 'Child4',
#        'Child5', 'Child6', 'Child7', 'Child8', 'Child9', 'Child10', 'Child11',
#        'Child12', 'Child13', 'Child14', 'Origin Parish', 'Race in Other',
#        'Location Other Race', 'Notes/URL', 'ecpp_id'],
#       dtype='object')

# %%
# 1790 census
config = {
    'ecpp_id_col': 'ecpp_id',
    'records_id_col': '#ID',
    'census': {
        'First Name': 'First',
        'Last Name': 'Last',
        'Gender': 'Gender',
        'Age': 'Age',
    },
    'baptisms': {
        'First Name': 'SpanishName',
        'Last Name': 'Surname',
        'Mother First Name': 'MSpanishName',
        'Mother Last Name': 'MSurname',
        'Father First Name': 'FSpanishName',
        'Father Last Name': 'FSurname',
        'Gender': 'Sex',
        'Age': 'Age',
    }
}

# %%
# # Padrones
# config = {
#     'ecpp_id_col': 'ecpp_id',
#     'records_id_col': '#ID',
#     'census': {
#         'First Name': 'Ego_First Name',
#         'Last Name': 'Ego_Last Name',
#         'Gender': 'Sex'
#         # 'Age': 'Age',
#     },
#     'baptisms': {
#         'First Name': 'SpanishName',
#         'Last Name': 'Surname',
#         'Mother First Name': 'MSpanishName',
#         'Mother Last Name': 'MSurname',
#         'Father First Name': 'FSpanishName',
#         'Father Last Name': 'FSurname',
#         'Gender': 'Sex'
#         # 'Age': 'Age',
#     }
# }

# %%
matcher = PersonMatcher(census=census, baptisms=baptisms, config=config)

# %%
# %%time
matched_results = matcher.create_matched_records()
# Out:
# CPU times: total: 50.4 s
# Wall time: 52.5 s

# %%
matched_results
# Out:
#            ecpp_id     #ID Census_First Census_Last Census_Gender  Census_Age  \
# 0                1       1         José  Zúñiga, de             m        34.0
# 1                1       2         José  Zúñiga, de             m        34.0
# 2                1       3         José  Zúñiga, de             m        34.0
# 3                1       4         José  Zúñiga, de             m        34.0
# 4                1       5         José  Zúñiga, de             m        34.0
# ...            ...     ...          ...         ...           ...         ...
# 104917675     1008  104081    Gertrudis    Arce, de             f        18.0
# 104917676     1008  104082    Gertrudis    Arce, de             f        18.0
# 104917677     1008  104083    Gertrudis    Arce, de             f        18.0
# 104917678     1008  104084    Gertrudis    Arce, de             f        18.0
# 104917679     1008  104085    Gertrudis    Arce, de             f        18.0
#
#                Baptisms_SpanishName Baptisms_Surname  Baptisms_MSpanishName  \
# 0                       Juan Joseph          Salazar       Maria del Loreto
# 1             Joseph Ignacio Matheo   Velasco y Lara  Maria Antonia Euvalda
# 2          Maria Estefana Valvanera            Villa            Maria Paula
# 3                     Maria Antonia          Quixada          Ju[a]na Maria
# 4                Juan Pedro Jacinto             Ruiz           Maria Isabel
# ...                             ...              ...                    ...
# 104917675              José Agustin             Ruis              Francisca
# 104917676              José Antonio          Higuera           Maria Loreta
# 104917677               Maria Santa             Soto             Maria Rita
# 104917678                    Felipe              NaN               Gregoria
# 104917679                   Nicolas              NaN                    NaN
#
#           Baptisms_MSurname Baptisms_FSpanishName Baptisms_FSurname  \
# 0                  Espinosa   José Loreto Salazar               NaN
# 1                    Campos       Joseph Fernando    Velasco y Lara
# 2                  Martines           Juan Joseph             Villa
# 3                   Armenta               Vicente           Quixada
# 4                   Armenta       Fructuoso Maria              Ruiz
# ...                     ...                   ...               ...
# 104917675              Ruis            [Unstated]               NaN
# 104917676               NaN             Pantaleon           Higuera
# 104917677           Arrieta          Juan Ysidoro              Soto
# 104917678               NaN            [Unstated]               NaN
# 104917679               NaN                   NaN               NaN
#
#           Baptisms_Sex Baptisms_Age
# 0                    M            0
# 1                    M           15
# 2                    F            3
# 3                    F           19
# 4                    M          NaN
# ...                ...          ...
# 104917675            M           22
# 104917676            M            1
# 104917677            F            1
# 104917678            M           13
# 104917679            M           60
#
# [104917680 rows x 14 columns]

# %%
# %%time
matcher.match()

# %%
filename = "matches/1790_census_matches.pkl"

# %%
matcher.matched_records
# Out:
#            ecpp_id     #ID Census_First Census_Last Census_Gender  Census_Age  \
# 0                1       1         José  Zúñiga, de             m        34.0
# 1                1       2         José  Zúñiga, de             m        34.0
# 2                1       3         José  Zúñiga, de             m        34.0
# 3                1       4         José  Zúñiga, de             m        34.0
# 4                1       5         José  Zúñiga, de             m        34.0
# ...            ...     ...          ...         ...           ...         ...
# 104917675     1008  104081    Gertrudis    Arce, de             f        18.0
# 104917676     1008  104082    Gertrudis    Arce, de             f        18.0
# 104917677     1008  104083    Gertrudis    Arce, de             f        18.0
# 104917678     1008  104084    Gertrudis    Arce, de             f        18.0
# 104917679     1008  104085    Gertrudis    Arce, de             f        18.0
#
#                Baptisms_SpanishName Baptisms_Surname  Baptisms_MSpanishName  \
# 0                       Juan Joseph          Salazar       Maria del Loreto
# 1             Joseph Ignacio Matheo   Velasco y Lara  Maria Antonia Euvalda
# 2          Maria Estefana Valvanera            Villa            Maria Paula
# 3                     Maria Antonia          Quixada          Ju[a]na Maria
# 4                Juan Pedro Jacinto             Ruiz           Maria Isabel
# ...                             ...              ...                    ...
# 104917675              José Agustin             Ruis              Francisca
# 104917676              José Antonio          Higuera           Maria Loreta
# 104917677               Maria Santa             Soto             Maria Rita
# 104917678                    Felipe              NaN               Gregoria
# 104917679                   Nicolas              NaN                    NaN
#
#           Baptisms_MSurname Baptisms_FSpanishName Baptisms_FSurname  \
# 0                  Espinosa   José Loreto Salazar               NaN
# 1                    Campos       Joseph Fernando    Velasco y Lara
# 2                  Martines           Juan Joseph             Villa
# 3                   Armenta               Vicente           Quixada
# 4                   Armenta       Fructuoso Maria              Ruiz
# ...                     ...                   ...               ...
# 104917675              Ruis            [Unstated]               NaN
# 104917676               NaN             Pantaleon           Higuera
# 104917677           Arrieta          Juan Ysidoro              Soto
# 104917678               NaN            [Unstated]               NaN
# 104917679               NaN                   NaN               NaN
#
#           Baptisms_Sex Baptisms_Age
# 0                    M            0
# 1                    M           15
# 2                    F            3
# 3                    F           19
# 4                    M          NaN
# ...                ...          ...
# 104917675            M           22
# 104917676            M            1
# 104917677            F            1
# 104917678            M           13
# 104917679            M           60
#
# [104917680 rows x 14 columns]

# %%
matcher.save_matched_records(filename)

# %%
# threshold_value = 0.75
# matcher.filter_records_by_score(threshold_value)
